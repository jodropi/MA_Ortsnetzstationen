# %%
###IMPORT
import numpy as np
import pandas as pd
import dataprocessing
from stochasticmodel import StochasticLoadModel, StochasticSimulationResult
import loaddata
import matplotlib.pyplot as plt
import seaborn as sns

# %reload_ext autoreload
# %autoreload 2

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '16'
})

# %%
stationen=loaddata.load_stations()
display(stationen)
# Out:
#                     Name  Hausanschluesse  Leistung Cluster Kurzname  Zaehler  \
# 0              Durchholz               73       400      W4        A       99
# 1         Guennemannshof               62       400      W1        B       72
# 2            Kaemperfeld               24       630      W3        C       40
# 3            Lutherplatz               53       630       S        D      394
# 4     Marienhospital alt               43       630       S        E      382
# 5                Querweg               26       400      W2        F       50
# 6            Rehnocken 1               19       200      W2        G       34
# 7  Rudolf-Koenig-Strasse               40       630       S        H      315
# 8       Schule Durchholz               53       400      W1        I       90
#
#    LeistungproHA  LeistungproZaehler  ZaehlerproHA
# 0       5.479452            4.040404      1.356164
# 1       6.451613            5.555556      1.161290
# 2      26.250000           15.750000      1.666667
# 3      11.886792            1.598985      7.433962
# 4      14.651163            1.649215      8.883721
# 5      15.384615            8.000000      1.923077
# 6      10.526316            5.882353      1.789474
# 7      15.750000            2.000000      7.875000
# 8       7.547170            4.444444      1.698113

# %%
list_power_d, list_power_yd, list_power_ysd, list_power_ymd, list_mat_power_d, list_power_ywd, list_power_yswd, list_power_only_d = loaddata.load_data_from_measurements([0,1,2,3,4,5,6,7,8], d=True, yd=True, ysd=True,ywd=True,yswd=True)
# Out:
# Lade Daten von Station  Durchholz
# Lade Daten von Station  Guennemannshof
# Lade Daten von Station  Kaemperfeld
# Lade Daten von Station  Lutherplatz
# Lade Daten von Station  Marienhospital alt
# Lade Daten von Station  Querweg
# Lade Daten von Station  Rehnocken 1
# Lade Daten von Station  Rudolf-Koenig-Strasse
# Lade Daten von Station  Schule Durchholz

# %%
MAPES=np.zeros([9,3])
all_sim=list()
all_ref=list()
all_res=list()
all_mape=list()

for station in range(0,9):
    station_no = station
    power_d = list_power_d[station_no]
    power_yd = list_power_yd[station_no]
    power_ysd = list_power_ysd[station_no]
    power_ywd = list_power_ywd[station_no]
    power_yswd = list_power_yswd[station_no]
    data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
    reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]
    mymodel=StochasticLoadModel(normalization=[4,0,1,2],order_regression=6)                 #[4,0,1,2]
    mymodel.parameterize(data_in=data_input,plots=False)
    res = mymodel.simulate(n_runs=1)
    energy_reference = 0.25*reference.sum().sum()
    denormalized_result=mymodel.denormalize(res,new_case_4=2,energy=energy_reference,max_value=reference.max().max())
    A, B, C, D = denormalized_result.analyze(reference,plots=False,show_tables=False, export_plots=False)
    MAPES[station,:]=A
    all_res.insert(len(all_res),denormalized_result)
    all_ref.insert(len(all_ref),B)
    all_sim.insert(len(all_sim),C)
    all_mape.insert(len(all_mape),D)
# Out:
# >>> Parmetrisiere ein stochastisches Modell...
# Normiere Daten gemaess: Normierung: 4 , Lokal/Global: 0 , Grenzen: 1 , Reskalierung: 2
# >>> Berechne alle Uebergangsmatrizen...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechnung der Uebergangsmatrizen abgeschlossen!
# >>> Parametrisierung abgeschlossen!
# >>> SIMULATION GESTARTET...
# >>> Starte Markov-Ketten-Simulation - Iteration 0
# Tag 0
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 1
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8518464852154668]
# Tag 2
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8938115517893899]
# Tag 3
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8114814373900314]
# Tag 4
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9154680725731155]
# Tag 5
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8584025805591704]
# Tag 6
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.880833311593655]
# Tag 7
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7669694519727281]
# Tag 8
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9470526577328888]
# Tag 9
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7102138626187531]
# Tag 10
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8004495971863681]
# Tag 11
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7823747569366339]
# Tag 12
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6594258391134447]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 13
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8521785639916463]
# Tag 14
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.737465242633285]
# Tag 15
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8107465224913144]
# Tag 16
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5408424537192945]
# Tag 17
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.852856516082485]
# Tag 18
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8366333161892956]
# Tag 19
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.817702992198895]
# Tag 20
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9068225493643762]
# Tag 21
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.826573391698464]
# Tag 22
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6442472585354757]
# Tag 23
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9036008186155614]
# Tag 24
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8105289934311377]
# Tag 25
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8473155304071691]
# Tag 26
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.9175384138184154]
# Tag 27
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9321670547015415]
# Tag 28
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7290300873417561]
# Tag 29
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9160305124566591]
# Tag 30
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8116758800949392]
# Tag 31
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7517459296705645]
# Tag 32
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9361878247987111]
# Tag 33
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7888662169440758]
# Tag 34
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.801394092437952]
# Tag 35
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8024385006699384]
# Tag 36
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.884502687894856]
# Tag 37
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7086260638232665]
# Tag 38
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7344263745464548]
# Tag 39
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8904528773429177]
# Tag 40
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.9013892178521176]
# Tag 41
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9292950930656708]
# Tag 42
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8794762793356933]
# Tag 43
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9734963387533214]
# Tag 44
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9059665730497733]
# Tag 45
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7227043132090185]
# Tag 46
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9161408695398919]
# Tag 47
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.9195010956460996]
# Tag 48
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8475775495153329]
# Tag 49
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7234222347548226]
# Tag 50
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8985241493596959]
# Tag 51
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7397791068550258]
# Tag 52
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8124937171783613]
# Tag 53
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8931430240194003]
# Tag 54
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.695378093162862]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 55
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8425024634738086]
# Tag 56
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7288554145960978]
# Tag 57
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.785732328971568]
# Tag 58
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7806255663099049]
# Tag 59
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8750228316370788]
# Tag 60
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8511426642806488]
# Tag 61
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8886075741787155]
# Tag 62
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9240400463056783]
# Tag 63
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7077686980278436]
# Tag 64
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8614921783832776]
# Tag 65
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8107207867783157]
# Tag 66
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8611018906185118]
# Tag 67
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8476776705263642]
# Tag 68
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7140089728920845]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 69
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8294561126649304]
# Tag 70
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8626134675588562]
# Tag 71
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9220282193241034]
# Tag 72
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9301211938518289]
# Tag 73
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8703616689100819]
# Tag 74
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9571178353154043]
# Tag 75
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8349700869966118]
# Tag 76
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8919603129459458]
# Tag 77
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7784096319235143]
# Tag 78
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9040064459100869]
# Tag 79
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.8076404454295237]
# Tag 80
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.37943202786589547]
# Tag 81
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.4395835529979123]
# Tag 82
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.6624699386261673]
# Tag 83
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.9027004962764927]
# Tag 84
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.7072692285104067]
# Tag 85
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3139817358125858]
# Tag 86
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.4086377425024317]
# Tag 87
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3908586897050014]
# Tag 88
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.8503401936522049]
# Tag 288
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.6014259481396709]
# Tag 289
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.5498010722062577]
# Tag 290
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.4341436184223221]
# Tag 291
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3983077626316421]
# Tag 292
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.38320938541780547]
# Tag 293
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.6459488664693034]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 2
# Tag 294
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.9020831548625989]
# Tag 295
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2791035363413582]
# Tag 296
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.8354931098477277]
# Tag 297
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.44502707876993347]
# Tag 298
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.35846482007100466]
# Tag 299
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.7840877592385164]
# Tag 300
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.8899850422820749]
# Tag 301
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.8883747235317462]
# Tag 302
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.36815737479940386]
# Tag 303
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.8161954376014836]
# Tag 304
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4167569323122453]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 305
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7763212531053878]
# Tag 306
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.766417254530567]
# Tag 307
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9267892408753732]
# Tag 308
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7115938448010967]
# Tag 309
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5814384828507514]
# Tag 310
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7675340564819415]
# Tag 311
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7881602451864214]
# Tag 312
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7240831942192035]
# Tag 313
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7724755386125137]
# Tag 314
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9796852812833099]
# Tag 315
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.857645262375163]
# Tag 316
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5424150420681195]
# Tag 317
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8322103574062151]
# Tag 318
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9422344812099591]
# Tag 319
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8987820995589791]
# Tag 320
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.96997314809834]
# Tag 321
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9078972805863434]
# Tag 322
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9948411022039868]
# Tag 323
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9669233290824567]
# Tag 324
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9136579209677556]
# Tag 325
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.825191546802815]
# Tag 326
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8245447594424076]
# Tag 327
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8781716485032167]
# Tag 328
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.9366235052138356]
# Tag 329
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.866663299904874]
# Tag 330
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8220606572450588]
# Tag 331
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.956762019646703]
# Tag 332
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8777752266133391]
# Tag 333
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9237588737810124]
# Tag 334
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6625656732052957]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 335
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8736980540994373]
# Tag 336
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8599843685163683]
# Tag 337
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.902835975267188]
# Tag 338
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8052494236526216]
# Tag 339
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8002215884716061]
# Tag 340
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9094848400383366]
# Tag 341
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.834293956750672]
# Tag 342
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.786484169580033]
# Tag 343
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7314377759462897]
# Tag 344
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9593209738258749]
# Tag 345
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9258199468459166]
# Tag 346
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.874227978255532]
# Tag 347
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6896264362278731]
# Tag 348
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7118567153982451]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 349
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8873907513049684]
# Tag 350
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8449893194744218]
# Tag 351
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8542493754215331]
# Tag 352
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8983471304766227]
# Tag 353
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9318565736074798]
# Tag 354
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7776404111780576]
# Tag 355
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7033123972550653]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 356
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.769960020475361]
# Tag 357
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.9651101282209529]
# Tag 358
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7775420828175205]
# Tag 359
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8721448644274195]
# Tag 360
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.859978616964643]
# Tag 361
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6842928936955185]
# Tag 362
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.9620580297591705]
# Tag 363
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8693826437884538]
# Tag 364
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8048853837909989]
# Gewuenschte Jahresenergie:  470587.56673775415 , resultierende mittlere Jahresleistung: 53.72004186504043
# >>> Simulation erfolgreich denormalisiert!
# MAPE von mean =  0.6275706101310317 % , MAPE von std =  6.205848101130446 %
# MAX Sim =  86.95682029121858 , MAX Mess =  89.45414453814162 , Abs Delta = 2.7917367717470363
# Jahresenergieverbrauch der Messdaten: 470587.56673775415  kWh
# >>> Parmetrisiere ein stochastisches Modell...
# Normiere Daten gemaess: Normierung: 4 , Lokal/Global: 0 , Grenzen: 1 , Reskalierung: 2
# >>> Berechne alle Uebergangsmatrizen...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechnung der Uebergangsmatrizen abgeschlossen!
# >>> Parametrisierung abgeschlossen!
# >>> SIMULATION GESTARTET...
# >>> Starte Markov-Ketten-Simulation - Iteration 0
# Tag 0
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 1
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7101325893774649]
# Tag 2
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.664879014854519]
# Tag 3
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7216110936786587]
# Tag 4
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.604969698220268]
# Tag 5
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5804113270095521]
# Tag 6
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.517753615300037]
# Tag 7
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.504579367556325]
# Tag 8
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5328407830440974]
# Tag 9
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.692992422992109]
# Tag 10
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6385339141360806]
# Tag 11
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6226944812291672]
# Tag 12
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7142388826617964]
# Tag 13
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7567979725064018]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 9
# Tag 14
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5644059498390106]
# Tag 15
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5532767468359024]
# Tag 16
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5421956307996209]
# Tag 17
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5592973077315653]
# Tag 18
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6571207245795985]
# Tag 19
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7158919393686358]
# Tag 20
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.5816547723392119]
# Tag 21
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.628325618536951]
# Tag 22
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5213141831947156]
# Tag 23
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5673180376783192]
# Tag 24
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6694281210648276]
# Tag 25
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5912339422913039]
# Tag 26
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5061228926635976]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 27
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7305536311005637]
# Tag 28
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.562989011805719]
# Tag 29
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.746347994738381]
# Tag 30
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6543460945116627]
# Tag 31
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6662551186355177]
# Tag 32
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7034150811809212]
# Tag 33
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.617663570395765]
# Tag 34
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7057208390146305]
# Tag 35
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6443013008695696]
# Tag 36
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.693026017570372]
# Tag 37
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5912178050558552]
# Tag 38
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6412795055109963]
# Tag 39
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5178748353401091]
# Tag 40
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7222151956834387]
# Tag 41
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.6242783318124212]
# Tag 42
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6361574998135187]
# Tag 43
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5546668206411769]
# Tag 44
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5132231461533552]
# Tag 45
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5511775254867032]
# Tag 46
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5403897265094554]
# Tag 47
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7210736559419596]
# Tag 48
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.6932376820693678]
# Tag 49
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5817260168540311]
# Tag 50
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7398421292412812]
# Tag 51
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7417835832569791]
# Tag 52
# ...
# Tag 217
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5707331630750225]
# Tag 218
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5237141878995532]
# Tag 219
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6877320089708941]
# Tag 220
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5646878471341159]
# Tag 221
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6520548800606009]
# Tag 222
# Starte Random-Walk an Tag 1  in Jahreszeit 2  mit Voergaenger-Leistung [0.5018979092175271]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 223
# Starte Random-Walk an Tag 2  in Jahreszeit 2  mit Voergaenger-Leistung [0.8661277617502464]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 9
# Tag 224
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5347464404119081]
# Tag 225
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.46760588682412]
# Tag 226
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6245019448904878]
# Tag 227
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.695635889009719]
# Tag 228
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5683175784189449]
# Tag 229
# Starte Random-Walk an Tag 1  in Jahreszeit 2  mit Voergaenger-Leistung [0.6046872253988906]
# Tag 230
# Starte Random-Walk an Tag 2  in Jahreszeit 2  mit Voergaenger-Leistung [0.6119086389864551]
# Tag 231
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6359587107585761]
# Tag 232
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6402674775246231]
# Tag 233
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.559766440082161]
# Tag 234
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.7288877401201588]
# Tag 235
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5535684865774603]
# Tag 236
# Starte Random-Walk an Tag 1  in Jahreszeit 2  mit Voergaenger-Leistung [0.7800019991077175]
# Tag 237
# Starte Random-Walk an Tag 2  in Jahreszeit 2  mit Voergaenger-Leistung [0.677856006051944]
# Tag 238
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5449520856449835]
# Tag 239
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5489781737430499]
# Tag 240
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5866059150072143]
# Tag 241
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.7318975517506822]
# Tag 242
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.7050231647235237]
# Tag 243
# Starte Random-Walk an Tag 1  in Jahreszeit 2  mit Voergaenger-Leistung [0.6806238500279074]
# Tag 244
# Starte Random-Walk an Tag 2  in Jahreszeit 2  mit Voergaenger-Leistung [0.7842823782911418]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 9
# Tag 245
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.7605678857432661]
# Tag 246
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5396148790121239]
# Tag 247
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5491909168548617]
# Tag 248
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6589236660096611]
# Tag 249
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5863729029613521]
# Tag 250
# Starte Random-Walk an Tag 1  in Jahreszeit 2  mit Voergaenger-Leistung [0.42277481291442937]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 251
# Starte Random-Walk an Tag 2  in Jahreszeit 2  mit Voergaenger-Leistung [0.6138348412118412]
# Tag 252
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5576714523094819]
# Tag 253
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.5465027085443921]
# Tag 254
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0.6966338006168176]
# Tag 255
# Starte Random-Walk an Tag 0  in Jahreszeit 2  mit Voergaenger-Leistung [0
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5826088403508554]
# Tag 351
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5123669452353258]
# Tag 352
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4786042975052225]
# Tag 353
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5737055185639545]
# Tag 354
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5684587360031956]
# Tag 355
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5298778121397141]
# Tag 356
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.576333587562996]
# Tag 357
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6113768215802536]
# Tag 358
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.5585806742974428]
# Tag 359
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4545333334106216]
# Tag 360
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5302022120355548]
# Tag 361
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4009387996992962]
# Tag 362
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5832101161889098]
# Tag 363
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.5612141053421819]
# Tag 364
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5351687567656777]
# Gewuenschte Jahresenergie:  390809.07271427265 , resultierende mittlere Jahresleistung: 44.612907844095055
# >>> Simulation erfolgreich denormalisiert!
# MAPE von mean =  0.4659521772968086 % , MAPE von std =  4.458923523050391 %
# MAX Sim =  67.41934589442798 , MAX Mess =  69.00591651374211 , Abs Delta = 2.299180562290155
# Jahresenergieverbrauch der Messdaten: 390809.07271427265  kWh

# %%
df=pd.DataFrame()
for i in [0,1,3,4,5,6,7,8]:
    df[str(i)]=all_mape[i]

# %%
plt.figure(figsize=(19.2,15))
sns.boxplot(data=df,width=0.5,color='tab:blue')
plt.grid()
plt.yticks(np.arange(0,110,10))
# Out:
# ([<matplotlib.axis.YTick at 0x246844fe3a0>,
#   <matplotlib.axis.YTick at 0x2468452ebe0>,
#   <matplotlib.axis.YTick at 0x24684527dc0>,
#   <matplotlib.axis.YTick at 0x24684417bb0>,
#   <matplotlib.axis.YTick at 0x246853b0340>,
#   <matplotlib.axis.YTick at 0x246853b0a90>,
#   <matplotlib.axis.YTick at 0x246853c3220>,
#   <matplotlib.axis.YTick at 0x246853c3970>,
#   <matplotlib.axis.YTick at 0x246853c3c10>,
#   <matplotlib.axis.YTick at 0x246853b0a60>,
#   <matplotlib.axis.YTick at 0x2468441a520>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
mi=pd.MultiIndex.from_product([np.arange(0,9,1), ['Simulation','Messdaten']])

# %%
max_vec_s=np.zeros([365,9])
max_vec_m=np.zeros([365,9])
for i in range(0,9):
    max_vec_s[:,i]=np.min(np.reshape(all_sim[i],[365,96],order='F'),axis=1)
    max_vec_m[:,i]=np.min(np.reshape(all_ref[i],[365,96],order='F'),axis=1)

# %%
times=np.arange(0,365,1)
allmax=pd.DataFrame(index=times,columns=mi)
for station in range(0,9):
    allmax[station,'Simulation']=max_vec_s[:,station]
    allmax[station,'Messdaten']=max_vec_m[:,station]
allmaxlong=allmax.stack(level=[0,1]).reset_index(level=0, drop=True).reset_index()

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '28'
})
#plt.figure(figsize=(19.2,9.6))
this_fig, this_ax=plt.subplots(figsize=(19.2,9.6))
sns.boxplot(x='level_0',y=0, data=allmaxlong, hue="level_1",width=0.5,hue_order=['Simulation','Messdaten'])
plt.xlabel('Ortsnetzsationen')
plt.ylabel('Leistung [kW]')
plt.xticks(np.arange(0,9,1),['A','B','C','D','E','F','G','H','I'])

handles, labels = this_ax.get_legend_handles_labels()
plt.legend(handles=handles[0:], labels=labels[0:])
plt.savefig('export/Boxplot_Alle_Minimalwerte.pdf',bbox_inches='tight')

# %%
times=np.arange(0,35040,1)

# %%
alldata=pd.DataFrame(index=times,columns=mi)
allmax=pd.DataFrame()

# %%
for station in range(0,9):
    alldata[station,'Simulation']=all_sim[station]
    alldata[station,'Messdaten']=all_ref[station]

# %%
alllong=alldata.stack(level=[0,1]).reset_index(level=0, drop=True).reset_index()

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '28'
})
#plt.figure(figsize=(19.2,9.6))
this_fig, this_ax=plt.subplots(figsize=(19.2,9.6))
sns.boxplot(x='level_0',y=0, data=alllong, hue="level_1",width=0.5,hue_order=['Simulation','Messdaten'])
plt.xlabel('Ortsnetzsationen')
plt.ylabel('Leistung [kW]')
plt.xticks(np.arange(0,9,1),['A','B','C','D','E','F','G','H','I'])

handles, labels = this_ax.get_legend_handles_labels()
plt.legend(handles=handles[0:], labels=labels[0:])
plt.savefig('Boxplot_Spektrum.pdf',bbox_inches='tight')

# %%
station_no = 3
power_d = list_power_d[station_no]
power_yd = list_power_yd[station_no]
power_ysd = list_power_ysd[station_no]
power_ywd = list_power_ywd[station_no]
power_yswd = list_power_yswd[station_no]
data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]

# %%
gruppe=[3,4,7]
gesamt_df=list()
for i in gruppe:
    df=list_power_yswd[i][2018]
    normed=df/df.max().max()
    gesamt_df.insert(len(gesamt_df),normed)

new_df=gesamt_df[0]
for j in range(1,len(gesamt_df)):
    new_df=pd.concat([new_df,gesamt_df[j]],axis=1,levels=['Jahreszeit'])

new_df1=new_df.copy()

gruppe=[4,7]
gesamt_df=list()
df3=list_power_yd[3][2018]/list_power_yd[3][2018].max().max()
df4=list_power_yd[4][2018]/list_power_yd[4][2018].max().max()
df7=list_power_yd[7][2018]/list_power_yd[7][2018].max().max()
df=df3+df4+df7
df=df/3

data_input=[new_df1,df,new_df1]

# %% [markdown]
# Parametrisierung

# %%
mymodel=StochasticLoadModel(normalization=[4,1,1,2],order_regression=6)                 #[4,0,1,2]
mymodel.parameterize(data_in=data_input,plots=False)

# %%
res = mymodel.simulate(n_runs=1)

# %%
energy_reference = 0.25*reference.sum().sum()
denormalized_result=mymodel.denormalize(res,new_case_4=4,energy=energy_reference,max_value=reference.max().max())
A, B, C = denormalized_result.analyze(reference,show_tables=False, export_plots=False,filename_plots='unbekannt_gruppe')

# %%
station_no = 7
power_d = list_power_d[station_no]
power_yd = list_power_yd[station_no]
power_ysd = list_power_ysd[station_no]
power_ywd = list_power_ywd[station_no]
power_yswd = list_power_yswd[station_no]
data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]
energy_reference = 0.25*reference.sum().sum()
denormalized_result=mymodel.denormalize(res,new_case_4=4,energy=energy_reference,max_value=reference.max().max())
A, B, C = denormalized_result.analyze(reference,show_tables=False, export_plots=False,filename_plots='unbekannt_gruppe')

# %%
maxwert=power_ysd[2018].max().max()
typedays_1 = power_ysd[2018]/maxwert
typedays_2={}
for season in range(0,3):
    for weekday in range(0,3):
        typedays_2[season,weekday]=typedays_1.loc[:,season].loc[:,weekday].mean(axis=1).to_numpy()

# %%
mymodel.checkconvergence(typedays_2,n_it=50)

# %% [markdown]
# Denormalisierung

# %% [markdown]
# Gruppen

# %%
"""
gruppe=[3,4,7]
gesamt_df=list()
for i in gruppe:
    df=list_power_yswd[i][2018]
    normed=df/df.max().max()
    gesamt_df.insert(len(gesamt_df),normed)

new_df=gesamt_df[0]
for j in range(1,len(gesamt_df)):
    new_df=pd.concat([new_df,gesamt_df[j]],axis=1,levels=['Jahreszeit'])

new_df1=new_df.copy()

gruppe=[4,7]
gesamt_df=list()
df3=list_power_yd[3][2018]/list_power_yd[3][2018].max().max()
df4=list_power_yd[4][2018]/list_power_yd[4][2018].max().max()
df7=list_power_yd[7][2018]/list_power_yd[7][2018].max().max()
df=df3+df4+df7
df=df/3

data_input=[new_df1,df,new_df1]
"""

# %% [markdown]
# Fragmente

# %%
pquer=mw[1]
pvor=mw[0]
pnach=mw[2]
pdelta=pnach-pvor
d=55

A=[[d**2, d],[(2*d+1)*(d+1)/6, (d+1)/2]]
invA=np.linalg.inv(A)
RHS=[[pnach-pvor],[pquer-pvor]]
coeff=np.dot(invA,RHS)
a=coeff[0]
b=coeff[1]
c=pvor

mypoly=np.poly1d([a,b,c])
X=np.linspace(0,55,56)
Y=mypoly(X)
plt.plot(X,Y)
Z=Y/pquer
plt.plot(X,Z)

# %%
pquer=mw[1]
pvor=mw[2]
pnach=mw[0]
pdelta=pnach-pvor
d=47

A=[[d**2, d],[(2*d+1)*(d+1)/6, (d+1)/2]]
invA=np.linalg.inv(A)
RHS=[[pnach-pvor],[pquer-pvor]]
coeff=np.dot(invA,RHS)
a=coeff[0]
b=coeff[1]
c=pvor

mypoly=np.poly1d([a,b,c])
X=np.linspace(0,55,56)
Y=mypoly(X)
plt.plot(X,Y)

# %%
"""
E_0=np.zeros(9)
E_1=np.zeros(9)
E_2=np.zeros(9)
E_mean=np.zeros(9)
for i in range(0,9):
    E_0[i]=0.25*list_power_ywd[i][2018].loc[:,0].sum(axis=0).mean()
    E_1[i]=0.25*list_power_ywd[i][2018].loc[:,1].sum(axis=0).mean()
    E_2[i]=0.25*list_power_ywd[i][2018].loc[:,2].sum(axis=0).mean()
    E_mean[i]=0.25*list_power_ywd[i][2018].sum(axis=0).mean()

factors_0=np.ones(9)
factors_1=np.ones(9)
factors_2=np.ones(9)
for i in range(0,9):
    factors_0[i]=E_0[i]/E_mean[i]
    factors_1[i]=E_1[i]/E_mean[i]
    factors_2[i]=E_2[i]/E_mean[i]

plt.figure()
plt.scatter([7,3,8,0,1,5,6,2,4],E_0)
plt.scatter([7,3,8,0,1,5,6,2,4],E_1)
plt.scatter([7,3,8,0,1,5,6,2,4],E_2)
plt.xticks(np.linspace(0,8,9),['D','E','H','B','I','F','G','A','C'])
plt.figure()
plt.scatter([7,3,8,0,1,5,6,2,4],factors_0)
plt.scatter([7,3,8,0,1,5,6,2,4],factors_1)
plt.scatter([7,3,8,0,1,5,6,2,4],factors_2)
plt.xticks(np.linspace(0,8,9),['D','E','H','B','I','F','G','A','C'])
"""
