# %%
###IMPORT
import numpy as np
import pandas as pd
import dataprocessing
from stochasticmodel import StochasticLoadModel, StochasticSimulationResult
import loaddata
import matplotlib.pyplot as plt
import seaborn as sns

# %reload_ext autoreload
# %autoreload 2

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '16'
})

# %%
stationen=loaddata.load_stations()
display(stationen)
# Out:
#                     Name  Hausanschluesse  Leistung Cluster Kurzname  Zaehler  \
# 0              Durchholz               73       400      W4        A       99
# 1         Guennemannshof               62       400      W1        B       72
# 2            Kaemperfeld               24       630      W3        C       40
# 3            Lutherplatz               53       630       S        D      394
# 4     Marienhospital alt               43       630       S        E      382
# 5                Querweg               26       400      W2        F       50
# 6            Rehnocken 1               19       200      W2        G       34
# 7  Rudolf-Koenig-Strasse               40       630       S        H      315
# 8       Schule Durchholz               53       400      W1        I       90
#
#    LeistungproHA  LeistungproZaehler  ZaehlerproHA
# 0       5.479452            4.040404      1.356164
# 1       6.451613            5.555556      1.161290
# 2      26.250000           15.750000      1.666667
# 3      11.886792            1.598985      7.433962
# 4      14.651163            1.649215      8.883721
# 5      15.384615            8.000000      1.923077
# 6      10.526316            5.882353      1.789474
# 7      15.750000            2.000000      7.875000
# 8       7.547170            4.444444      1.698113

# %%
list_power_d, list_power_yd, list_power_ysd, list_power_ymd, list_mat_power_d, list_power_ywd, list_power_yswd, list_power_only_d = loaddata.load_data_from_measurements([0,1,2,3,4,5,6,7,8], d=True, yd=True, ysd=True,ywd=True,yswd=True)
# Out:
# Lade Daten von Station  Durchholz
# Lade Daten von Station  Guennemannshof
# Lade Daten von Station  Kaemperfeld
# Lade Daten von Station  Lutherplatz
# Lade Daten von Station  Marienhospital alt
# Lade Daten von Station  Querweg
# Lade Daten von Station  Rehnocken 1
# Lade Daten von Station  Rudolf-Koenig-Strasse
# Lade Daten von Station  Schule Durchholz

# %%
MAPES=np.zeros([9,3])
all_sim=list()
all_ref=list()
all_res=list()
all_mape=list()

for station in range(0,9):
    station_no = station
    power_d = list_power_d[station_no]
    power_yd = list_power_yd[station_no]
    power_ysd = list_power_ysd[station_no]
    power_ywd = list_power_ywd[station_no]
    power_yswd = list_power_yswd[station_no]
    data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
    reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]
    mymodel=StochasticLoadModel(normalization=[4,1,1,2],order_regression=6)                 #[4,0,1,2]
    mymodel.parameterize(data_in=data_input,plots=False)
    res = mymodel.simulate(n_runs=1)
    energy_reference = 0.25*reference.sum().sum()
    denormalized_result=mymodel.denormalize(res,new_case_4=4,energy=energy_reference,max_value=reference.max().max())
    A, B, C, D = denormalized_result.analyze(reference,plots=False,show_tables=False, export_plots=False)
    MAPES[station,:]=A
    all_res.insert(len(all_res),denormalized_result)
    all_ref.insert(len(all_ref),B)
    all_sim.insert(len(all_sim),C)
    all_mape.insert(len(all_mape),D)
# Out:
# >>> Parmetrisiere ein stochastisches Modell...
# Normiere Daten gemaess: Normierung: 4 , Lokal/Global: 1 , Grenzen: 1 , Reskalierung: 2
# >>> Berechne alle Uebergangsmatrizen...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechnung der Uebergangsmatrizen abgeschlossen!
# >>> Parametrisierung abgeschlossen!
# >>> SIMULATION GESTARTET...
# >>> Starte Markov-Ketten-Simulation - Iteration 0
# Tag 0
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 1
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.829132322135962]
# Tag 2
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.85292318411548]
# Tag 3
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7352418944309413]
# Tag 4
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7047595627612812]
# Tag 5
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6746087035364837]
# Tag 6
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7337067187837052]
# Tag 7
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.83438059646186]
# Tag 8
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6814425509439657]
# Tag 9
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7469292286876477]
# Tag 10
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7298624823482305]
# Tag 11
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6506949186739006]
# Tag 12
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7553337757912009]
# Tag 13
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8350279752882953]
# Tag 14
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5442061255389865]
# Tag 15
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8417709050173975]
# Tag 16
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.580898677245387]
# Tag 17
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7275090971543655]
# Tag 18
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.47709135166136485]
# Tag 19
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7769243233391682]
# Tag 20
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.6405857809367906]
# Tag 21
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7907353104007087]
# Tag 22
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5312004766402753]
# Tag 23
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7990405585825153]
# Tag 24
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7497829015234744]
# Tag 25
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7787992785559519]
# Tag 26
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7332947668250713]
# Tag 27
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7418975805569406]
# Tag 28
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5687061824727186]
# Tag 29
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6779798153926955]
# Tag 30
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7997950612537383]
# Tag 31
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8267885411256201]
# Tag 32
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.866135303307502]
# Tag 33
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8641899640562172]
# Tag 34
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7367659500197637]
# Tag 35
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8604352576455311]
# Tag 36
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.9037620519911346]
# Tag 37
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.638462758551991]
# Tag 38
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7800724513911558]
# Tag 39
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8402201399574013]
# Tag 40
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8149573338304752]
# Tag 41
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7268753237805694]
# Tag 42
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8647336104093317]
# Tag 43
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7324571655665676]
# Tag 44
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8273032453787279]
# Tag 45
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.561548768743539]
# Tag 46
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8194959125375768]
# Tag 47
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.8262846993245909]
# Tag 48
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7854213967127094]
# Tag 49
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.579459203036053]
# Tag 50
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7103735878972202]
# Tag 51
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7393084297752682]
# Tag 52
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7052318271742809]
# Tag 53
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7664190106982218]
# Tag 54
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7274362886230243]
# Tag 55
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8106272794397295]
# Tag 56
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6046457104405009]
# Tag 57
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7404208950680987]
# Tag 58
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8183559166297535]
# Tag 59
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7995982969627775]
# Tag 60
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.743471211519318]
# Tag 61
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5394486239725736]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 62
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.6181057341753494]
# Tag 63
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7295549348903647]
# Tag 64
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7163202559738859]
# Tag 65
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8259995271264547]
# Tag 66
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6854410053590859]
# Tag 67
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8493691206774335]
# Tag 68
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.7306773503141633]
# Tag 69
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.7404769573341211]
# Tag 70
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7640981087651572]
# Tag 71
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7752107045978216]
# Tag 72
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8726712102238573]
# Tag 73
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5401012141157878]
# Tag 74
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.8220012646512045]
# Tag 75
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.72116306287348]
# Tag 76
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8076308552748458]
# Tag 77
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.517673173870184]
# Tag 78
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.7520315903004997]
# Tag 79
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.6840365144651464]
# Tag 80
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.5282028825359151]
# Tag 81
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.26255425025948576]
# Tag 82
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.4936457508364063]
# Tag 83
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.3368838075388523]
# Tag 84
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.23752800231041266]
# Tag 85
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.8942884250474383]
# Tag 364
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6380924465352648]
# Gewuenschte Jahresenergie:  470587.56673775415 , resultierende mittlere Jahresleistung: 53.72004186504043
# >>> Simulation erfolgreich denormalisiert!
# MAPE von mean =  1.184914953160479 % , MAPE von std =  2.3288380347233786 %
# MAX Sim =  91.56367109192446 , MAX Mess =  89.45414453814162 , Abs Delta = 2.358221147465536
# Jahresenergieverbrauch der Messdaten: 470587.56673775415  kWh
# >>> Parmetrisiere ein stochastisches Modell...
# Normiere Daten gemaess: Normierung: 4 , Lokal/Global: 1 , Grenzen: 1 , Reskalierung: 2
# >>> Berechne alle Uebergangsmatrizen...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechne Uebergangsmatrix...
# >>> Berechnung der Uebergangsmatrizen abgeschlossen!
# >>> Parametrisierung abgeschlossen!
# >>> SIMULATION GESTARTET...
# >>> Starte Markov-Ketten-Simulation - Iteration 0
# Tag 0
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 1
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.42852749572761856]
# Tag 2
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6105117187148607]
# Tag 3
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.41990859296805455]
# Tag 4
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5804715122488492]
# Tag 5
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4086746730806491]
# Tag 6
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4715360949597973]
# Tag 7
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.44800619298715155]
# Tag 8
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5419824481753668]
# Tag 9
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.42151566307525073]
# Tag 10
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.33620174590738205]
# Tag 11
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3921495484798594]
# Tag 12
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.35933487288869637]
# Tag 13
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.493090455054901]
# Tag 14
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.41232004314916526]
# Tag 15
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3908478667797982]
# Tag 16
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.37631230746103084]
# Tag 17
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3383411858230295]
# Tag 18
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5080804760525884]
# Tag 19
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4002261445633082]
# Tag 20
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.39634883225158224]
# Tag 21
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.419137882950223]
# Tag 22
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3564645777730723]
# Tag 23
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.31477788958029457]
# Tag 24
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5691792882744715]
# Tag 25
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5642335567036932]
# Tag 26
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.35279429413809793]
# Tag 27
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4853852442599798]
# Tag 28
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4258437207530233]
# Tag 29
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5989275314969937]
# Tag 30
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6683627281715678]
# Tag 31
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.37575242028627737]
# Tag 32
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.570121060032657]
# Tag 33
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.34742820872744107]
# Tag 34
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.39159318906089874]
# Tag 35
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.36662007638786465]
# Tag 36
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5235938088274956]
# Tag 37
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3332004816612694]
# Tag 38
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.32768959875529546]
# Tag 39
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3474349464492069]
# Tag 40
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5824601329646371]
# Tag 41
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4727375521392362]
# Tag 42
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4352534219817167]
# Tag 43
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4020519722753598]
# Tag 44
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6574193982663236]
# Tag 45
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4831881200234649]
# Tag 46
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5062831971427091]
# Tag 47
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.33498958155399655]
# Tag 48
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4404566501082342]
# Tag 49
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.35427908498352945]
# Tag 50
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6886566141192597]
# Tag 51
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3732545273789499]
# Tag 52
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.39981500626679656]
# Tag 53
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.44804772230814577]
# Tag 54
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.6171740769770784]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 6
# Tag 55
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.39703164957468756]
# Tag 56
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.42663184387560804]
# Tag 57
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.6928212510552768]
# Tag 58
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.42153159206232893]
# Tag 59
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.47944084392712694]
# Tag 60
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3476105403751086]
# Tag 61
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.39173475857697493]
# Tag 62
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.363828569898277]
# Tag 63
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5177261263425114]
# Tag 64
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5677393467783662]
# Tag 65
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4661748404945226]
# Tag 66
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.30570639430453367]
# Tag 282
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3586435432960176]
# Tag 283
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3149359699525624]
# Tag 284
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2627859871910548]
# Tag 285
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.30330909211619905]
# Tag 286
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.32899986524400965]
# Tag 287
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3471012397774813]
# Tag 288
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.20259699137386916]
# Tag 289
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.27456914076732897]
# Tag 290
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.27323700272096785]
# Tag 291
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2595839562032435]
# Tag 292
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.35039047215856794]
# Tag 293
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.3761045876370812]
# Tag 294
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2803276340750718]
# Tag 295
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.45548492022631215]
# Tag 296
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2143912434329424]
# Tag 297
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.37421102740779916]
# Tag 298
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.29277850208238293]
# Tag 299
# Starte Random-Walk an Tag 1  in Jahreszeit 1  mit Voergaenger-Leistung [0.2963000040512952]
# Tag 300
# Starte Random-Walk an Tag 2  in Jahreszeit 1  mit Voergaenger-Leistung [0.3614064848144199]
# Tag 301
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.2309979880492816]
# Tag 302
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.23849361981471331]
# Tag 303
# Starte Random-Walk an Tag 0  in Jahreszeit 1  mit Voergaenger-Leistung [0.3220569178414029]
# Tag 304
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.2526398811444161]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 305
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.46432147395003487]
# Tag 306
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.41413378260672395]
# Tag 307
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.42787014318697536]
# Tag 308
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4166511471159834]
# Tag 309
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4532553655413652]
# Tag 310
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.48097051068646696]
# Tag 311
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4374635173790319]
# Tag 312
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.40738114668544206]
# Tag 313
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.37571121300941845]
# Tag 314
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4805928823158727]
# Tag 315
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.48225681123312536]
# Tag 316
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4240803573392094]
# Tag 317
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.37569509985617694]
# Tag 318
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3942962577036913]
# Tag 319
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4464317650683279]
# Tag 320
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.5125935373264638]
# Tag 321
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.3991122205265629]
# Tag 322
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5046245608471008]
# Tag 323
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.39515433256524063]
# Tag 324
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.41699561639721694]
# Tag 325
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.33831478198537396]
# Tag 326
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4214417139960314]
# Tag 327
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.3401894955136887]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 0
# Tag 328
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4713787257954137]
# Tag 329
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.44046462149760723]
# Tag 330
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.405493009036922]
# Tag 331
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4066507892071799]
# Tag 332
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4021985818733331]
# Tag 333
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.37032914322174776]
# Tag 334
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4274680563682836]
# Tag 335
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.5010584567270013]
# Tag 336
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4419243272836322]
# Tag 337
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3876356908688349]
# Tag 338
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.417744169425775]
# Tag 339
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4232322163922517]
# Tag 340
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3895881968616206]
# Tag 341
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.3935799907633461]
# Tag 342
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.3998410109528159]
# Tag 343
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.407482677748083]
# Tag 344
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.44817061469723185]
# Tag 345
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.5135817616566146]
# Tag 346
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.48038850992435644]
# Tag 347
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.37149570362537104]
# Tag 348
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.37163516293612764]
# Tag 349
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4865281253019859]
# Tag 350
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.46748720831682317]
# Tag 351
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4196094180278927]
# Tag 352
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.4239015716003702]
# Tag 353
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.3106646441719521]
# Tag 354
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.40403785769236095]
# Tag 355
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4049914773091302]
# Tag 356
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.47905796006417134]
# Tag 357
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4563876924061978]
# Tag 358
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.3818350128319546]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 1
# Tag 359
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.4547253230614289]
# Tag 360
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.34874860713780903]
# Tag 361
# Starte Random-Walk an Tag 0  in Jahreszeit 0  mit Voergaenger-Leistung [0.39606937164472206]
# Tag 362
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.4465915460175547]
# Tag 363
# Starte Random-Walk an Tag 2  in Jahreszeit 0  mit Voergaenger-Leistung [0.3708555279323296]
# Vorgaenger-Leistung nicht zulaessig! Neuer Vorgaenger-Zustand: 1
# Tag 364
# Starte Random-Walk an Tag 1  in Jahreszeit 0  mit Voergaenger-Leistung [0.39611391941558843]
# Gewuenschte Jahresenergie:  390809.07271427265 , resultierende mittlere Jahresleistung: 44.612907844095055
# >>> Simulation erfolgreich denormalisiert!
# MAPE von mean =  0.6066402607225395 % , MAPE von std =  1.8222595659037535 %
# MAX Sim =  70.24874147531379 , MAX Mess =  69.00591651374211 , Abs Delta = 1.8010411633677585
# Jahresenergieverbrauch der Messdaten: 390809.07271427265  kWh

# %%
df=pd.DataFrame()
for i in [0,1,3,4,5,6,7,8]:
    df[str(i)]=all_mape[i]

# %%
plt.figure(figsize=(19.2,15))
sns.boxplot(data=df,width=0.5,color='tab:blue')
plt.grid()
plt.yticks(np.arange(0,110,10))
# Out:
# ([<matplotlib.axis.YTick at 0x207ec635fa0>,
#   <matplotlib.axis.YTick at 0x207ec635820>,
#   <matplotlib.axis.YTick at 0x207ec62d790>,
#   <matplotlib.axis.YTick at 0x207ece650a0>,
#   <matplotlib.axis.YTick at 0x207ece656d0>,
#   <matplotlib.axis.YTick at 0x207ece65e20>,
#   <matplotlib.axis.YTick at 0x207ece65ac0>,
#   <matplotlib.axis.YTick at 0x207ece58ee0>,
#   <matplotlib.axis.YTick at 0x207ece6a3a0>,
#   <matplotlib.axis.YTick at 0x207ece6aaf0>,
#   <matplotlib.axis.YTick at 0x207ece73280>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
mi=pd.MultiIndex.from_product([np.arange(0,9,1), ['Simulation','Messdaten']])

# %%
max_vec_s=np.zeros([365,9])
max_vec_m=np.zeros([365,9])
for i in range(0,9):
    max_vec_s[:,i]=np.min(np.reshape(all_sim[i],[365,96],order='F'),axis=1)
    max_vec_m[:,i]=np.min(np.reshape(all_ref[i],[365,96],order='F'),axis=1)

# %%
times=np.arange(0,365,1)
allmax=pd.DataFrame(index=times,columns=mi)
for station in range(0,9):
    allmax[station,'Simulation']=max_vec_s[:,station]
    allmax[station,'Messdaten']=max_vec_m[:,station]
allmaxlong=allmax.stack(level=[0,1]).reset_index(level=0, drop=True).reset_index()

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '28'
})
#plt.figure(figsize=(19.2,9.6))
this_fig, this_ax=plt.subplots(figsize=(19.2,9.6))
sns.boxplot(x='level_0',y=0, data=allmaxlong, hue="level_1",width=0.5,hue_order=['Simulation','Messdaten'])
plt.xlabel('Ortsnetzsationen')
plt.ylabel('Leistung [kW]')
plt.xticks(np.arange(0,9,1),['A','B','C','D','E','F','G','H','I'])

handles, labels = this_ax.get_legend_handles_labels()
plt.legend(handles=handles[0:], labels=labels[0:])
plt.savefig('export/Boxplot_Alle_Minimalwerte.pdf',bbox_inches='tight')

# %%
times=np.arange(0,35040,1)

# %%
alldata=pd.DataFrame(index=times,columns=mi)
allmax=pd.DataFrame()

# %%
for station in range(0,9):
    alldata[station,'Simulation']=all_sim[station]
    alldata[station,'Messdaten']=all_ref[station]

# %%
alllong=alldata.stack(level=[0,1]).reset_index(level=0, drop=True).reset_index()

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": '28'
})
#plt.figure(figsize=(19.2,9.6))
this_fig, this_ax=plt.subplots(figsize=(19.2,9.6))
sns.boxplot(x='level_0',y=0, data=alllong, hue="level_1",width=0.5,hue_order=['Simulation','Messdaten'])
plt.xlabel('Ortsnetzsationen')
plt.ylabel('Leistung [kW]')
plt.xticks(np.arange(0,9,1),['A','B','C','D','E','F','G','H','I'])

handles, labels = this_ax.get_legend_handles_labels()
plt.legend(handles=handles[0:], labels=labels[0:])
plt.savefig('Boxplot_Spektrum.pdf',bbox_inches='tight')

# %%
station_no = 3
power_d = list_power_d[station_no]
power_yd = list_power_yd[station_no]
power_ysd = list_power_ysd[station_no]
power_ywd = list_power_ywd[station_no]
power_yswd = list_power_yswd[station_no]
data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]

# %%
gruppe=[3,4,7]
gesamt_df=list()
for i in gruppe:
    df=list_power_yswd[i][2018]
    normed=df/df.max().max()
    gesamt_df.insert(len(gesamt_df),normed)

new_df=gesamt_df[0]
for j in range(1,len(gesamt_df)):
    new_df=pd.concat([new_df,gesamt_df[j]],axis=1,levels=['Jahreszeit'])

new_df1=new_df.copy()

gruppe=[4,7]
gesamt_df=list()
df3=list_power_yd[3][2018]/list_power_yd[3][2018].max().max()
df4=list_power_yd[4][2018]/list_power_yd[4][2018].max().max()
df7=list_power_yd[7][2018]/list_power_yd[7][2018].max().max()
df=df3+df4+df7
df=df/3

data_input=[new_df1,df,new_df1]

# %% [markdown]
# Parametrisierung

# %%
mymodel=StochasticLoadModel(normalization=[4,1,1,2],order_regression=6)                 #[4,0,1,2]
mymodel.parameterize(data_in=data_input,plots=False)

# %%
res = mymodel.simulate(n_runs=1)

# %%
energy_reference = 0.25*reference.sum().sum()
denormalized_result=mymodel.denormalize(res,new_case_4=4,energy=energy_reference,max_value=reference.max().max())
A, B, C = denormalized_result.analyze(reference,show_tables=False, export_plots=False,filename_plots='unbekannt_gruppe')

# %%
station_no = 7
power_d = list_power_d[station_no]
power_yd = list_power_yd[station_no]
power_ysd = list_power_ysd[station_no]
power_ywd = list_power_ywd[station_no]
power_yswd = list_power_yswd[station_no]
data_input = [power_yswd[2018], power_yd[2018],power_yswd[2018]]
reference = power_yd[2018]     #list_power_only_d[1].iloc[:,177:542]
energy_reference = 0.25*reference.sum().sum()
denormalized_result=mymodel.denormalize(res,new_case_4=4,energy=energy_reference,max_value=reference.max().max())
A, B, C = denormalized_result.analyze(reference,show_tables=False, export_plots=False,filename_plots='unbekannt_gruppe')

# %%
maxwert=power_ysd[2018].max().max()
typedays_1 = power_ysd[2018]/maxwert
typedays_2={}
for season in range(0,3):
    for weekday in range(0,3):
        typedays_2[season,weekday]=typedays_1.loc[:,season].loc[:,weekday].mean(axis=1).to_numpy()

# %%
mymodel.checkconvergence(typedays_2,n_it=50)

# %% [markdown]
# Denormalisierung

# %% [markdown]
# Gruppen

# %%
"""
gruppe=[3,4,7]
gesamt_df=list()
for i in gruppe:
    df=list_power_yswd[i][2018]
    normed=df/df.max().max()
    gesamt_df.insert(len(gesamt_df),normed)

new_df=gesamt_df[0]
for j in range(1,len(gesamt_df)):
    new_df=pd.concat([new_df,gesamt_df[j]],axis=1,levels=['Jahreszeit'])

new_df1=new_df.copy()

gruppe=[4,7]
gesamt_df=list()
df3=list_power_yd[3][2018]/list_power_yd[3][2018].max().max()
df4=list_power_yd[4][2018]/list_power_yd[4][2018].max().max()
df7=list_power_yd[7][2018]/list_power_yd[7][2018].max().max()
df=df3+df4+df7
df=df/3

data_input=[new_df1,df,new_df1]
"""

# %% [markdown]
# Fragmente

# %%
pquer=mw[1]
pvor=mw[0]
pnach=mw[2]
pdelta=pnach-pvor
d=55

A=[[d**2, d],[(2*d+1)*(d+1)/6, (d+1)/2]]
invA=np.linalg.inv(A)
RHS=[[pnach-pvor],[pquer-pvor]]
coeff=np.dot(invA,RHS)
a=coeff[0]
b=coeff[1]
c=pvor

mypoly=np.poly1d([a,b,c])
X=np.linspace(0,55,56)
Y=mypoly(X)
plt.plot(X,Y)
Z=Y/pquer
plt.plot(X,Z)

# %%
pquer=mw[1]
pvor=mw[2]
pnach=mw[0]
pdelta=pnach-pvor
d=47

A=[[d**2, d],[(2*d+1)*(d+1)/6, (d+1)/2]]
invA=np.linalg.inv(A)
RHS=[[pnach-pvor],[pquer-pvor]]
coeff=np.dot(invA,RHS)
a=coeff[0]
b=coeff[1]
c=pvor

mypoly=np.poly1d([a,b,c])
X=np.linspace(0,55,56)
Y=mypoly(X)
plt.plot(X,Y)

# %%
"""
E_0=np.zeros(9)
E_1=np.zeros(9)
E_2=np.zeros(9)
E_mean=np.zeros(9)
for i in range(0,9):
    E_0[i]=0.25*list_power_ywd[i][2018].loc[:,0].sum(axis=0).mean()
    E_1[i]=0.25*list_power_ywd[i][2018].loc[:,1].sum(axis=0).mean()
    E_2[i]=0.25*list_power_ywd[i][2018].loc[:,2].sum(axis=0).mean()
    E_mean[i]=0.25*list_power_ywd[i][2018].sum(axis=0).mean()

factors_0=np.ones(9)
factors_1=np.ones(9)
factors_2=np.ones(9)
for i in range(0,9):
    factors_0[i]=E_0[i]/E_mean[i]
    factors_1[i]=E_1[i]/E_mean[i]
    factors_2[i]=E_2[i]/E_mean[i]

plt.figure()
plt.scatter([7,3,8,0,1,5,6,2,4],E_0)
plt.scatter([7,3,8,0,1,5,6,2,4],E_1)
plt.scatter([7,3,8,0,1,5,6,2,4],E_2)
plt.xticks(np.linspace(0,8,9),['D','E','H','B','I','F','G','A','C'])
plt.figure()
plt.scatter([7,3,8,0,1,5,6,2,4],factors_0)
plt.scatter([7,3,8,0,1,5,6,2,4],factors_1)
plt.scatter([7,3,8,0,1,5,6,2,4],factors_2)
plt.xticks(np.linspace(0,8,9),['D','E','H','B','I','F','G','A','C'])
"""
